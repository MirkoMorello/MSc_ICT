# %% [markdown]
# # L07

# %% [markdown]
# Going on from Speaker Diarization

# %% [markdown]
# ## Diarization Error Rate (DER):
# It is measured as the fraction of time that is not attributed correctly to a speaker or non-speech.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Speaker Emotion Recognition

# %% [markdown]
# Russel and Lisa Feldman Barrett's theory. It states every emotion can be decomposed into primary emotions. This is our goal.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When talking about the dataset language is important, it changes the range of emotions expressed.
