# %% [markdown]
# # L17

# %% [markdown]
# # Human activity Recognition

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we can also arrange the features in a different way:
#
# - 6 features, the sensors (h) 150 samples (w, time) and only 1 channel (depth)
# - 1 feature (h) 150 samples (w, time) and 6 channels, the sensors (depth), apply conv1D
